# %%
import json

# %%
with open("disease_questions_map.json","r") as fp:
    dqm=json.load(fp)

# %%
dqm
# Out:
# {'skin': ['itching',
#   'skin_rash',
#   'nodal_skin_eruptions',
#   'dischromic _patches',
#   'continuous_sneezing',
#   'shivering',
#   'chills',
#   'watering_from_eyes',
#   'stomach_pain',
#   'burning_micturition',
#   'spotting_ urination',
#   'fatigue',
#   'lethargy',
#   'high_fever',
#   'headache',
#   'loss_of_appetite',
#   'mild_fever',
#   'swelled_lymph_nodes',
#   'malaise',
#   'red_spots_over_body',
#   'pus_filled_pimples',
#   'blackheads',
#   'scurring'],
#  'stomach': ['stomach_pain',
#   'acidity',
#   'ulcers_on_tongue',
#   'vomiting',
#   'cough',
#   'chest_pain',
#   'indigestion',
#   'loss_of_appetite',
#   'abdominal_pain',
#   'passage_of_gases',
#   'internal_itching',
#   'sunken_eyes',
#   'dehydration',
#   'diarrhoea',
#   'skin_rash',
#   'joint_pain',
#   'skin_peeling',
#   'silver_like_dusting',
#   'small_dents_in_nails',
#   'inflammatory_nails',
#   'high_fever',
#   'blister',
#   'red_sore_around_nose',
#   'yellow_crust_ooze'],
# ...

# %%
dqm_final={}
for key,value in dqm.items():
    temp=[]
    for val in value:
        print(val)
        temp.append("Are you suffering from {}?".format(val))
    dqm_final[key]=temp
# Out:
# itching
# skin_rash
# nodal_skin_eruptions
# dischromic _patches
# continuous_sneezing
# shivering
# chills
# watering_from_eyes
# stomach_pain
# burning_micturition
# spotting_ urination
# fatigue
# lethargy
# high_fever
# headache
# loss_of_appetite
# mild_fever
# swelled_lymph_nodes
# malaise
# red_spots_over_body
# pus_filled_pimples
# blackheads
# scurring
# stomach_pain
# acidity
# ulcers_on_tongue
# vomiting
# cough
# chest_pain
# indigestion
# loss_of_appetite
# abdominal_pain
# passage_of_gases
# internal_itching
# sunken_eyes
# dehydration
# diarrhoea
# skin_rash
# joint_pain
# skin_peeling
# silver_like_dusting
# small_dents_in_nails
# inflammatory_nails
# high_fever
# blister
# red_sore_around_nose
# yellow_crust_ooze
# fatigue
# cough
# high_fever
# breathlessness
# family_history
# mucoid_sputum
# chills
# vomiting
# weight_loss
# sweating
# loss_of_appetite
# mild_fever
# yellowing_of_eyes
# swelled_lymph_nodes
# malaise
# phlegm
# chest_pain
# blood_in_sputum
# ...

# %%
dqm_final.values()
# Out:
# dict_values([['Are you suffering from itching?', 'Are you suffering from skin_rash?', 'Are you suffering from nodal_skin_eruptions?', 'Are you suffering from dischromic _patches?', 'Are you suffering from continuous_sneezing?', 'Are you suffering from shivering?', 'Are you suffering from chills?', 'Are you suffering from watering_from_eyes?', 'Are you suffering from stomach_pain?', 'Are you suffering from burning_micturition?', 'Are you suffering from spotting_ urination?', 'Are you suffering from fatigue?', 'Are you suffering from lethargy?', 'Are you suffering from high_fever?', 'Are you suffering from headache?', 'Are you suffering from loss_of_appetite?', 'Are you suffering from mild_fever?', 'Are you suffering from swelled_lymph_nodes?', 'Are you suffering from malaise?', 'Are you suffering from red_spots_over_body?', 'Are you suffering from pus_filled_pimples?', 'Are you suffering from blackheads?', 'Are you suffering from scurring?'], ['Are you suffering from stomach_pain?', '
# ...
